# %% [markdown]
# # Title: 2020 U.S. Election
# #### Student ID:
# ##### Abby Arroyo: 2670127
# ##### Angie Chen: 2704746
# ##### Michelle Do: 2666960
# ##### Susanna Wang: 2671220

# %% [markdown]
# ## Introduction:
# The 2020 elections included the presidential, Senate, and House elections. Analyzing voter data and trends is vital for understanding the political climate and the changing times. The goal of this data analysis is to compare voter party data with the party that won that state. We are going to be looking at whether independent voter proportions are influenced by the margin by which the state votes red or blue. To further analyze the data, we want to compare the presidential party that won in the state with the party that won in the Senate and House and see if trends arise. Along with these, we also want to see if there are trends specifically related to presidential swing states, such as how the Senate and House votes compare to which party the states end up choosing in the presidential election. Finally, we wanted to compare whether the margin of winning the presidential election has an effect on the Senate and House party voting proportions. These analyses are relevant since it allows us to see the influences of independent votes and swing states.
#
# After this analysis, we found that there is a higher proportion of independent voters when republicans win the presidential election, but there is a general trend where, as the margin of winning increases, the proportion of independent voters also increases. When matching the state’s party in the presidential election with the other elections, we found that political parties match the state’s presidential, house, and governor votes, but not the senate votes. An interesting finding we found for swing state data was that half of the swing states agreed when comparing presidential and House party or presidential and Senate party, but only ⅛ of the swing states agreed for all three parties. There were no obvious patterns when looking at the House and Senate party voting proportions compared to what the state ended up voting for in the presidential election, but there was a slight trend in the state voting for the same party through all three institutions. Finally, after looking at the margin of victory in the presidential election compared to the proportion of party votes in the House, we saw that the party that won would have a higher proportion of the House votes, too. This was expected; however, the results for the Senate surprised us since the opposite party of the one that won the presidential election won the Senate votes. This project will first explain our data, the cleaning process, the merging procedure, and then the main columns used. Then we will go through each of our subquestions with the code used to come to our results, and a summary of our findings. At the very end, there will be a discussion of our findings and the information we extracted from the data.

# %% [markdown]
# ## Data Description:
#
# One of the datasets we will be using is president_county_candidate. It has 32177 rows and 6 columns. It contains every state and their counties. It shows each county's number of votes for each presidential candidate and who won for each county. The party of each candidate is also listed. Each row is relevant and shows: a state, a county, a presidential candidate, the party of the presidential candidate, the number of votes for that presidential candidate, and if that candidate won in the county.
#
# The "governors_county_candidate" dataset shows state governor election results at the county-level. Each row, or observation, represents a candidate's results in a particular county. The variables include the state and county in which the candidate ran, candidate name, their affiliated political party, total votes the candidate received in that county, and whether they won in that specific county.
#
# Each observation in the "house_candidate" describes voting results for a candidates in a particular district. Unlike the previous datasets, a state can elect more than one house representative. Winning in one district meant representing the state in the house. Additionally, the data is collected at the district-level, so I must clean it by adding a "State" column to group the districts into appropriate states.
#
# The "senate_county_candidate" dataset shows senate election results at the county-level. Each row, or observation, represents a candidate's results in a particular county. The variables include the state and county in which the candidate ran, candidate name, their affiliated political party, total votes the candidate received in that county.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pres = pd.read_csv("4-US_Election_2020/president_county_candidate.csv")
house = pd.read_csv("4-US_Election_2020/house_candidate.csv")
sen = pd.read_csv("4-US_Election_2020/senate_county_candidate.csv")
gov = pd.read_csv("4-US_Election_2020/governors_county_candidate.csv")

# %%
print(f"president_county_candidate number of rows and columns, repectively: {pres.shape}")
print()
print(f"house_candidate number of rows and columns, respectively: {house.shape}")
print()
print(f"senate_county_candidate number of rows and columns, respectively: {sen.shape}")
print()
print(f"governor_county_candidate number of rows and columns, respectively: {gov.shape}")
# Out:
# president_county_candidate number of rows and columns, repectively: (32177, 6)
#
# house_candidate number of rows and columns, respectively: (1215, 5)
#
# senate_county_candidate number of rows and columns, respectively: (14125, 5)
#
# governor_county_candidate number of rows and columns, respectively: (5145, 6)

# %% [markdown]
# ##### Description of data cleaning:
# The presidential data is cleaned so it shows the proportion of Democratic, Republican, and Independent votes for each state and the party of the president the state voted for. All parties that are not Democrat or Republican are recoded to Independent. Finally, the winner in each state is decided by comparing the proportion of votes for each party.
#
# Analagous procedures are conducted for the senate and governor datasets as well.
#
# The "house_candidate" dataset only describes the district making it difficult to extract information at the state-level for each winning candidate. I have to sort the districts into appropriate U.S. states and appended the resulting list as a new column labeled "States". Also, I must consider the extraneous "0th district" that doesn't actually belong to any state. Because there are a different number of representatives for each state, I recode for HOUSE MAJORITY, or the political party that a majority of the winners align with.

# %%
#The data table produced by this code shows the proportion of Democrat, Republican, and Independent votes for each state and the party of the president the state voted for.
# Code for cleaning the presidential data so it shows Democratic, Republican, and Independent party proportions
states = []
prop_dem = []
prop_rep = []
prop_ind = []
winner = []

for group in pres.groupby("state"): #groupby groups the data by state. group includes the state name and then all its associated data
    state_name = group[0] #grabs the state name of a group
    state_data = group[1] #grabs the data that corresponds to the state name
    states.append(state_name)

    total = 0 #total number of votes
    dem = 0 #number of democrats
    rep = 0 #number of republicans
    ind = 0 #number of independents
    prop_dems = 0 #proportion of democratic votes
    prop_reps = 0 #proportion of republican votes
    prop_inds = 0 #proportion of independent votes
    win = "no one" #party of the president the state voted for

    for votes, party in zip(state_data["total_votes"], state_data["party"]): #loops through "total_votes" and "party" for each state
        total = total + votes #calculates total votes for each state
        if party == "DEM": #these statements count the number of democrat, republican and independent votes respectively
            dem = dem + votes
        elif party == "REP":
            rep = rep + votes
        else:
            ind = ind + votes
    
    prop_dems = dem/total #proportion of democratic votes
    prop_reps = rep/total #proportion of republican votes
    prop_inds = ind/total #proportion of independent votes

    prop_dem.append(prop_dems)
    prop_rep.append(prop_reps)
    prop_ind.append(prop_inds)   

    if prop_dems > prop_reps and prop_dems > prop_inds: #these statements determine which party won
        win = "DEM"
    elif prop_reps > prop_dems and prop_reps > prop_inds:
        win = "REP"
    else:
        win = "IND"

    winner.append(win)

#creates a new dataframe with the proportions of votes for each party and the winner for each state
pres_proportions = pd.DataFrame({"State": states, "Proportion_Democrat": prop_dem, "Proportion_Republican":prop_rep, "Proportion_Independent": prop_ind, "Winner": winner}).round(3)
display(pres_proportions.head())

###########################################################################################################################################################################################

# Code for cleaning the house_candidate data so it shows votor data for each state in the house and excludes the extraneous district

states_list = [ #keyword list to that Boolean in FOR loop below selects from
    "Alabama", "Alaska", "Arizona", "Arkansas", "California",
    "Colorado", "Connecticut", "Delaware", "Florida", "Georgia",
    "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa",
    "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland",
    "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri",
    "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey",
    "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio",
    "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina",
    "South Dakota", "Tennessee", "Texas", "Utah", "Vermont",
    "West Virginia", "Washington", "Virginia", "Wisconsin", "Wyoming"
]
States = []

for district in house["district"]: #for every obs. in "district" column
    for index in range(len(states_list)): # go through every keyword in states_list
        if states_list[index] in district: # Is the state is listed in the district name
            States.append(states_list[index]) 
            break #do not need to check for the state after
    else:
        States.append("None") #consider the "United State's 0th district" = None

house["States"] = States #append newly assigned states list as new variable column

placeholder_winner = house.query("(district == 'United States’s 0th district') and (won == True)").index #Find the extra district not belonging to any state
house.iloc[placeholder_winner, -2] = False # set "won" = False to make exclude this district from the agg. winner's list later on 

###########################################################################################################################################################################################

# Code for recoding the house_candidate data so it shows democratic, republican, and independent party proportions for each state
house_winners_agg = house.query("won == True") #we are only interested in the house candidates that won

states = []
prop_dem = []
prop_rep = []
prop_ind = []
winner = []
total_reps = []

for group in house_winners_agg.groupby("States"): #groupby groups the data by state. group includes the state name and then all its associated data
    state_name = group[0] #grabs the state name of a group
    state_data = group[1] #grabs the data that corresponds to the state name
    states.append(state_name)

    total = 0 #total number of votes
    dem = 0 #number of democrats
    rep = 0 #number of republicans
    ind = 0 #number of independents
    prop_dems = 0 #proportion of democratic votes
    prop_reps = 0 #proportion of republican votes
    prop_inds = 0 #proportion of independent votes
    win = "no one" #party of the president the state voted for

    for party in state_data["party"]: #loops through "total_votes" and "party" for each state
        total = total + 1 #calculates total votes for each state
        if party == "DEM": #these statements count the number of democrat, republican and independent votes respectively
            dem = dem + 1
        elif party == "REP":
            rep = rep + 1
        else:
            ind = ind + 1
    
    prop_dems = dem/total #proportion of democratic votes
    prop_reps = rep/total #proportion of republican votes
    prop_inds = ind/total #proportion of independent votes

    prop_dem.append(prop_dems)
    prop_rep.append(prop_reps)
    prop_ind.append(prop_inds)  
    total_reps.append(total)

    if prop_dems > prop_reps and prop_dems > prop_inds: #these statements determine which party won
        win = "DEM"
    elif prop_reps > prop_dems and prop_reps > prop_inds:
        win = "REP"
    elif prop_dems == prop_reps:
        win = "TIE"
    else:
        win = "IND"

    winner.append(win)

#creates a new dataframe with the proportions of votes for each party and the winner for each state
house_proportions = pd.DataFrame({"State": states, "Proportion_Democrat": prop_dem, "Proportion_Republican":prop_rep, "Proportion_Independent": prop_ind,"Total_Reps": total_reps, "House_Majority": winner})



# Code for cleaning the governors data so it shows Democratic, Republican, and Independent party proportions
states = []
prop_dem = []
prop_rep = []
prop_ind = []
winner = []

for group in gov.groupby("state"): #groupby groups the data by state. group includes the state name and then all its associated data
    state_name = group[0] #grabs the state name of a group
    state_data = group[1] #grabs the data that corresponds to the state name
    states.append(state_name)

    total = 0 #total number of votes
    dem = 0 #number of democrats
    rep = 0 #number of republicans
    ind = 0 #number of independents
    prop_dems = 0 #proportion of democratic votes
    prop_reps = 0 #proportion of republican votes
    prop_inds = 0 #proportion of independent votes
    win = "no one" #party of the president the state voted for

    for votes, party in zip(state_data["votes"], state_data["party"]): #loops through "total_votes" and "party" for each state
        total = total + votes #calculates total votes for each state
        if party == "DEM": #these statements count the number of democrat, republican and independent votes respectively
            dem = dem + votes
        elif party == "REP":
            rep = rep + votes
        else:
            ind = ind + votes
    
    prop_dems = dem/total #proportion of democratic votes
    prop_reps = rep/total #proportion of republican votes
    prop_inds = ind/total #proportion of independent votes

    prop_dem.append(prop_dems)
    prop_rep.append(prop_reps)
    prop_ind.append(prop_inds)   

    if prop_dems > prop_reps and prop_dems > prop_inds: #these statements determine which party won
        win = "DEM"
    elif prop_reps > prop_dems and prop_reps > prop_inds:
        win = "REP"
    else:
        win = "IND"

    winner.append(win)

#creates a new dataframe with the proportions of votes for each party and the winner for each state
governor_proportions = pd.DataFrame({"State": states, "Proportion_Democrat": prop_dem, "Proportion_Republican":prop_rep, "Proportion_Independent": prop_ind, "Governor_Party": winner})



# Code for cleaning the senate data so it shows democratic, republican, and independent party proportions for each state
states = []
prop_dem = []
prop_rep = []
prop_ind = []
winner = []

for group in sen.groupby("state"): #groupby groups the data by state. group includes the state name and then all its associated data
    state_name = group[0] #grabs the state name of a group
    state_data = group[1] #grabs the data that corresponds to the state name
    states.append(state_name)

    total = 0 #total number of votes
    dem = 0 #number of democrats
    rep = 0 #number of republicans
    ind = 0 #number of independents
    prop_dems = 0 #proportion of democratic votes
    prop_reps = 0 #proportion of republican votes
    prop_inds = 0 #proportion of independent votes
    win = "no one" #party of the president the state voted for

    for votes, party in zip(state_data["total_votes"], state_data["party"]): #loops through "total_votes" and "party" for each state
        total = total + votes #calculates total votes for each state
        if party == "DEM": #these statements count the number of democrat, republican and independent votes respectively
            dem = dem + votes
        elif party == "REP":
            rep = rep + votes
        else:
            ind = ind + votes
    
    prop_dems = dem/total #proportion of democratic votes
    prop_reps = rep/total #proportion of republican votes
    prop_inds = ind/total #proportion of independent votes

    prop_dem.append(prop_dems)
    prop_rep.append(prop_reps)
    prop_ind.append(prop_inds)   

    if prop_dems > prop_reps and prop_dems > prop_inds: #these statements determine which party won
        win = "DEM"
    elif prop_reps > prop_dems and prop_reps > prop_inds:
        win = "REP"
    else:
        win = "IND"

    winner.append(win)

#creates a new dataframe with the proportions of votes for each party and the winner for each state
sen_proportions = pd.DataFrame({"State": states, "Proportion_Democrat": prop_dem, "Proportion_Republican":prop_rep, "Proportion_Independent": prop_ind, "Winner": winner})
# Out:
#         State  Proportion_Democrat  Proportion_Republican  \
# 0     Alabama                0.366                  0.620
# 1      Alaska                0.392                  0.485
# 2     Arizona                0.494                  0.491
# 3    Arkansas                0.348                  0.624
# 4  California                0.635                  0.343
#
#    Proportion_Independent Winner
# 0                   0.014    REP
# 1                   0.123    REP
# 2                   0.016    DEM
# 3                   0.028    REP
# 4                   0.022    DEM

# %% [markdown]
# ##### Description about merging procedure:
# Merge dataframe of overall presidential party, party of elected senator, party of elected governor, and majority party of elected house representatives for each state.
# For swing states: merge dataframe of overall presidential party, party of elected senator, party of elected governor, and majority party of elected house representatives for each swing state.

# %%
state_senator = pd.merge(left = pres_proportions[["State", "Winner", "Proportion_Democrat", "Proportion_Republican"]], #merge elected senator party df with elected presidential party df
    right = sen_proportions[["State", "Winner", "Proportion_Democrat", "Proportion_Republican"]], 
    how = "left", on = "State")

state_senator = state_senator.rename(columns = {"Winner_y": "Senator_Party", #change column names
                                                "Winner_x": "Winner",
                                                "Proportion_Democrat_x" : "pres_prop_dem",
                                                "Proportion_Republican_x" : "pres_prop_rep",
                                                "Proportion_Democrat_y" : "sen_prop_dem",
                                                "Proportion_Republican_y" : "sen_prop_rep"})

state_senator_house = pd.merge(left = state_senator, #add house majority party df with merged one from above
    right = house_proportions[["State", "House_Majority", "Proportion_Democrat", "Proportion_Republican"]], 
    how = "left", on = "State")

state_senator_house = state_senator_house.rename(columns = {"Proportion_Democrat": "house_prop_dem", #change column names
                                                            "Proportion_Republican": "house_prop_rep"})


merged = pd.merge(left = state_senator_house, # final merge by adding governor political party df 
    right = governor_proportions[["State", "Governor_Party", "Proportion_Democrat", "Proportion_Republican"]], 
    how = "left", on = "State")

merged = merged.rename(columns = {"Proportion_Democrat": "gov_prop_dem", #change column names
                                  "Proportion_Republican": "gov_prop_rep"})

display(merged)
# Out:
#                    State Winner  pres_prop_dem  pres_prop_rep Senator_Party  \
# 0                Alabama    REP          0.366          0.620           DEM
# 1                 Alaska    REP          0.392          0.485           DEM
# 2                Arizona    DEM          0.494          0.491           REP
# 3               Arkansas    REP          0.348          0.624           IND
# 4             California    DEM          0.635          0.343           NaN
# 5               Colorado    DEM          0.554          0.419           REP
# 6            Connecticut    DEM          0.592          0.392           NaN
# 7               Delaware    DEM          0.588          0.398           REP
# 8   District of Columbia    DEM          0.921          0.054           NaN
# 9                Florida    REP          0.479          0.512           NaN
# 10               Georgia    DEM          0.495          0.493           REP
# 11                Hawaii    DEM          0.637          0.343           NaN
# 12                 Idaho    REP          0.331          0.638           DEM
# 13              Illinois    DEM          0.589          0.391           REP
# 14               Indiana    REP          0.410          0.570           NaN
# 15                  Iowa    REP          0.449          0.531           DEM
# 16                Kansas    REP          0.414          0.562           DEM
# 17              Kentucky    REP          0.362          0.621           DEM
# 18             Louisiana    REP          0.399          0.585           DEM
# 19                 Maine    DEM          0.529          0.442           DEM
# 20              Maryland    DEM          0.654          0.322           NaN
# 21         Massachusetts    DEM          0.656          0.321           REP
# 22              Michigan    DEM          0.506          0.478           DEM
# 23             Minnesota    DEM          0.524          0.453           REP
# 24           Mississippi    REP          0.410          0.575           DEM
# 25              Missouri    REP          0.414          0.568           NaN
# 26               Montana    REP          0.404          0.567           DEM
# 27              Nebraska    REP          0.392          0.582           DEM
# 28                Nevada    DEM          0.501          0.477           NaN
# 29         New Hampshire    DEM          0.528          0.455           REP
# 30            New Jersey    DEM          0.571          0.413           REP
# 31            New Mexico    DEM          0.543          0.435           REP
# 32              New York    DEM          0.609          0.377           NaN
# 33        North Carolina    REP          0.486          0.499           REP
# 34          North Dakota    REP          0.318          0.651           NaN
# 35                  Ohio    REP          0.452          0.533           NaN
# 36              Oklahoma    REP          0.323          0.654           DEM
# 37                Oregon    DEM          0.565          0.404           REP
# 38          Pennsylvania    DEM          0.500          0.488           NaN
# 39          Rhode Island    DEM          0.593          0.387           REP
# 40        South Carolina    REP          0.434          0.551           DEM
# 41          South Dakota    REP          0.356          0.618           DEM
# 42             Tennessee    REP          0.374          0.607           DEM
# 43                 Texas    REP          0.465          0.520           REP
# 44                  Utah    REP          0.376          0.581           NaN
# 45               Vermont    DEM          0.661          0.307           NaN
# 46              Virginia    DEM          0.541          0.440           REP
# 47            Washington    DEM          0.580          0.388           NaN
# 48         West Virginia    REP          0.297          0.686           DEM
# 49             Wisconsin    DEM          0.495          0.488           NaN
# 50               Wyoming    REP          0.266          0.699           DEM
#
#     sen_prop_dem  sen_prop_rep House_Majority  house_prop_dem  house_prop_rep  \
# 0       0.745786      0.249344            REP        0.142857        0.857143
# 1       0.590108      0.294475            REP        0.000000        1.000000
# 2       0.173511      0.825695            DEM        0.555556        0.444444
# 3       0.000000      0.228876            REP        0.000000        1.000000
# 4            NaN           NaN            DEM        0.792453        0.207547
# 5       0.350723      0.589283            DEM        0.571429        0.428571
# 6            NaN           NaN            DEM        1.000000        0.000000
# 7       0.298814      0.631578            DEM        1.000000        0.000000
# 8            NaN           NaN            NaN             NaN             NaN
# 9            NaN           NaN            REP        0.407407        0.592593
# 10      0.405144      0.544882            REP        0.428571        0.571429
# 11           NaN           NaN            DEM        1.000000        0.000000
# 12      0.834971      0.052484            REP        0.000000        1.000000
# 13      0.210579      0.625000            DEM        0.722222        0.277778
# 14           NaN           NaN            REP        0.222222        0.777778
# 15      0.513389      0.414488            REP        0.250000        0.750000
# 16      0.456977      0.422607            REP        0.250000        0.750000
# 17      0.615055      0.276022            REP        0.166667        0.833333
# 18      0.822176      0.085683            REP        0.166667        0.833333
# 19      0.546745      0.294795            DEM        1.000000        0.000000
# 20           NaN           NaN            DEM        0.875000        0.125000
# 21      0.077258      0.898904            DEM        1.000000        0.000000
# 22      0.529049      0.425138            TIE        0.500000        0.500000
# 23      0.361925      0.456819            TIE        0.500000        0.500000
# 24      0.666199      0.284435            REP        0.250000        0.750000
# 25           NaN           NaN            REP        0.250000        0.750000
# 26      0.597679      0.402321            REP        0.000000        1.000000
# 27      0.573958      0.000000            REP        0.000000        1.000000
# 28           NaN           NaN            DEM        0.750000        0.250000
# 29      0.242595      0.701714            DEM        1.000000        0.000000
# 30      0.241354      0.709759            DEM        0.833333        0.166667
# 31      0.213179      0.719281            DEM        0.666667        0.333333
# 32           NaN           NaN            DEM        0.703704        0.296296
# 33      0.423432      0.466471            REP        0.384615        0.615385
# 34           NaN           NaN            REP        0.000000        1.000000
# 35           NaN           NaN            REP        0.250000        0.750000
# 36      0.883133      0.000000            REP        0.000000        1.000000
# 37      0.292074      0.609676            DEM        0.800000        0.200000
# 38           NaN           NaN            TIE        0.500000        0.500000
# 39      0.061050      0.938950            DEM        1.000000        0.000000
# 40      0.727278      0.239846            REP        0.142857        0.857143
# 41      0.980254      0.019746            REP        0.000000        1.000000
# 42      0.658772      0.258763            REP        0.222222        0.777778
# 43      0.465067      0.467064            REP        0.361111        0.638889
# 44           NaN           NaN            REP        0.000000        1.000000
# 45           NaN           NaN            DEM        1.000000        0.000000
# 46      0.329312      0.670688            DEM        0.636364        0.363636
# 47           NaN           NaN            DEM        0.700000        0.300000
# 48      0.908603      0.000000            REP        0.000000        1.000000
# 49           NaN           NaN            REP        0.375000        0.625000
# 50      0.922293      0.077707            REP        0.000000        1.000000
#
#    Governor_Party  gov_prop_dem  gov_prop_rep
# 0             NaN           NaN           NaN
# 1             NaN           NaN           NaN
# 2             NaN           NaN           NaN
# 3             NaN           NaN           NaN
# 4             NaN           NaN           NaN
# 5             NaN           NaN           NaN
# 6             NaN           NaN           NaN
# 7             DEM      0.594564      0.386314
# 8             NaN           NaN           NaN
# 9             NaN           NaN           NaN
# 10            NaN           NaN           NaN
# 11            NaN           NaN           NaN
# 12            NaN           NaN           NaN
# 13            NaN           NaN           NaN
# 14            REP      0.320520      0.565069
# 15            NaN           NaN           NaN
# 16            NaN           NaN           NaN
# 17            NaN           NaN           NaN
# 18            NaN           NaN           NaN
# 19            NaN           NaN           NaN
# 20            NaN           NaN           NaN
# 21            NaN           NaN           NaN
# 22            NaN           NaN           NaN
# 23            NaN           NaN           NaN
# 24            NaN           NaN           NaN
# 25            REP      0.406925      0.571064
# 26            REP      0.415615      0.544326
# 27            NaN           NaN           NaN
# 28            NaN           NaN           NaN
# 29            REP      0.333801      0.651623
# 30            NaN           NaN           NaN
# 31            NaN           NaN           NaN
# 32            NaN           NaN           NaN
# 33            DEM      0.515156      0.470054
# 34            REP      0.266931      0.692339
# 35            NaN           NaN           NaN
# 36            NaN           NaN           NaN
# 37            NaN           NaN           NaN
# 38            NaN           NaN           NaN
# 39            NaN           NaN           NaN
# 40            NaN           NaN           NaN
# 41            NaN           NaN           NaN
# 42            NaN           NaN           NaN
# 43            NaN           NaN           NaN
# 44            REP      0.303489      0.629768
# 45            REP      0.273535      0.684876
# 46            NaN           NaN           NaN
# 47            DEM      0.565578      0.431181
# 48            REP      0.304820      0.640371
# 49            NaN           NaN           NaN
# 50            NaN           NaN           NaN

# %%
display(round(merged.describe(), 2))
# Out:
#        pres_prop_dem  pres_prop_rep  sen_prop_dem  sen_prop_rep  \
# count          51.00          51.00         34.00         34.00
# mean            0.49           0.49          0.49          0.41
# std             0.12           0.12          0.27          0.27
# min             0.27           0.05          0.00          0.00
# 25%             0.40           0.41          0.29          0.24
# 50%             0.49           0.49          0.49          0.42
# 75%             0.57           0.58          0.66          0.62
# max             0.92           0.70          0.98          0.94
#
#        house_prop_dem  house_prop_rep  gov_prop_dem  gov_prop_rep
# count           50.00           50.00         11.00         11.00
# mean             0.45            0.55          0.39          0.57
# std              0.36            0.36          0.12          0.10
# min              0.00            0.00          0.27          0.39
# 25%              0.15            0.26          0.30          0.51
# 50%              0.40            0.60          0.33          0.57
# 75%              0.74            0.85          0.47          0.65
# max              1.00            1.00          0.59          0.69

# %% [markdown]
# #### Description of main columns:
#
# pres_prop_dem and pres_prop_rep contain the proportion of votes for the Democratic and Republican candidates in each state, respectively. sen_prop_dem/sen_prop_rep and gov_prop_dem/gov_prop_rep are the senate and governor analogs to pres_prop_dem/pres_prop_rep. Finally, house_prop_dem and house_prop_rep denote the proportion of the house that belong to the Democrat and Republican parties, respectively (in other words, the proportion of house members for each state that are from each party).
#
# From the table of descriptive statistics, we can infer that:
# * The presidential dataset contains all 50 states + Washington DC; house has all 50 states but not DC.
# * The senate dataset contains only 34 states, and governor only contains 11.
# * The mean proportion of votes for the Democratic candidate across all states is equal to the mean proportion of votes for the Republican candidate across all states (not greatly Democrat or Republican "leaning")
# * Senate is more democrat "leaning".
# * House is more republican "leaning".
# * Governor is more republican "leaning".

# %% [markdown]
# ## Results:

# %% [markdown]
# #### Subquestion 1: Are states that vote Democrat or Republican for president more likely to vote for Independent candidates?

# %% [markdown]
# The data table below shows the average proportion of independent votes for states that vote democrat or republican for president.

# %%
#groups pres_proportions by "Winner" which is the party the state voted for president.
#Proportion_Independent"].mean() takes the mean of the proportion of independent votes for democratic and republican states
ind_prop_party = pres_proportions.groupby(by = "Winner")["Proportion_Independent"].mean().round(3)
display(ind_prop_party)

party = ["Democrat", "Republican"]
count = [ind_prop_party.iloc[0],ind_prop_party.iloc[1]] #Grabs the proportion of indpendent votes for democrats and republicans respectively
plt.bar(x=party, height=count)
plt.xlabel("State Presidential Winning Party")
plt.ylabel("Average Proportion of Independent Votes")
plt.title("Average Proportion of Independent Votes by State Presidential Winning Party")
plt.show()
# Out:
# Winner
# DEM    0.021
# REP    0.026
# Name: Proportion_Independent, dtype: float64

# %% [markdown]
# We found that there was a greater average proportion of independent votes in states that voted republican for president by about 5%. We would need to do further analysis to see if there was a statistically significant difference between the two.

# %% [markdown]
# #### Subquestion 2: Are states with a greater mix of Republicans and Democrats more likely to have more votes for an independent candidate?

# %%
#this creates a new column that shows the winning margin for each state by subtracting the proportion of republican votes from the proportion of democratic votes. A positive value shows that Democrats won and a negative value shows that republicans won.
pres_proportions["Dem-Rep"] = pres_proportions["Proportion_Democrat"] - pres_proportions["Proportion_Republican"]
display(pres_proportions)

#this creates new x and y values without the outliers
no_out_x = pres_proportions["Dem-Rep"].loc[(pres_proportions["Dem-Rep"] < 0.5) & (pres_proportions["Dem-Rep"] > -0.5) & (pres_proportions["Proportion_Independent"] < 0.06)]
no_out_y = pres_proportions["Proportion_Independent"].loc[(pres_proportions["Dem-Rep"] < 0.5) & (pres_proportions["Dem-Rep"] > -0.5) & (pres_proportions["Proportion_Independent"] < 0.06)]

plt.scatter(no_out_x, no_out_y)
plt.xlim(-0.5, 0.5) 
plt.ylim(0, 0.05)
plt.xlabel("Proportion Democrat - Proportion Republican per State")
plt.ylabel("Proportion Independent")
plt.title("Proportion of Independent Votes vs. Victory Margin")

#this creates the first line that shows the line of best fit for the margins where republicans won (negative margin)
first_pres = no_out_x.loc[pres_proportions["Dem-Rep"] < 0]
first_ind = no_out_y.loc[pres_proportions["Dem-Rep"] < 0]
coefficients = np.polyfit(first_pres, first_ind, 1)
slope, intercept = coefficients
best_fit_line = slope * first_pres + intercept
plt.plot(first_pres, best_fit_line, color='red', label='Best Fit Line (Rep Win)')


#this creates the second line that shows the line of best fit for the margins where democrats won (positive margin)
sec_pres = no_out_x.loc[pres_proportions["Dem-Rep"] > 0]
sec_ind = no_out_y.loc[pres_proportions["Dem-Rep"] > 0]
coefficients = np.polyfit(sec_pres, sec_ind, 1)
slope, intercept = coefficients
best_fit_line = slope * sec_pres + intercept
plt.plot(sec_pres, best_fit_line, color='blue', label='Best Fit Line (Dem Win)')

plt.legend()
plt.show()
# Out:
#                    State  Proportion_Democrat  Proportion_Republican  \
# 0                Alabama                0.366                  0.620
# 1                 Alaska                0.392                  0.485
# 2                Arizona                0.494                  0.491
# 3               Arkansas                0.348                  0.624
# 4             California                0.635                  0.343
# 5               Colorado                0.554                  0.419
# 6            Connecticut                0.592                  0.392
# 7               Delaware                0.588                  0.398
# 8   District of Columbia                0.921                  0.054
# 9                Florida                0.479                  0.512
# 10               Georgia                0.495                  0.493
# 11                Hawaii                0.637                  0.343
# 12                 Idaho                0.331                  0.638
# 13              Illinois                0.589                  0.391
# 14               Indiana                0.410                  0.570
# 15                  Iowa                0.449                  0.531
# 16                Kansas                0.414                  0.562
# 17              Kentucky                0.362                  0.621
# 18             Louisiana                0.399                  0.585
# 19                 Maine                0.529                  0.442
# 20              Maryland                0.654                  0.322
# 21         Massachusetts                0.656                  0.321
# 22              Michigan                0.506                  0.478
# 23             Minnesota                0.524                  0.453
# 24           Mississippi                0.410                  0.575
# 25              Missouri                0.414                  0.568
# 26               Montana                0.404                  0.567
# 27              Nebraska                0.392                  0.582
# 28                Nevada                0.501                  0.477
# 29         New Hampshire                0.528                  0.455
# 30            New Jersey                0.571                  0.413
# 31            New Mexico                0.543                  0.435
# 32              New York                0.609                  0.377
# 33        North Carolina                0.486                  0.499
# 34          North Dakota                0.318                  0.651
# 35                  Ohio                0.452                  0.533
# 36              Oklahoma                0.323                  0.654
# 37                Oregon                0.565                  0.404
# 38          Pennsylvania                0.500                  0.488
# 39          Rhode Island                0.593                  0.387
# 40        South Carolina                0.434                  0.551
# 41          South Dakota                0.356                  0.618
# 42             Tennessee                0.374                  0.607
# 43                 Texas                0.465                  0.520
# 44                  Utah                0.376                  0.581
# 45               Vermont                0.661                  0.307
# 46              Virginia                0.541                  0.440
# 47            Washington                0.580                  0.388
# 48         West Virginia                0.297                  0.686
# 49             Wisconsin                0.495                  0.488
# 50               Wyoming                0.266                  0.699
#
#     Proportion_Independent Winner  Dem-Rep
# 0                    0.014    REP   -0.254
# 1                    0.123    REP   -0.093
# 2                    0.016    DEM    0.003
# 3                    0.028    REP   -0.276
# 4                    0.022    DEM    0.292
# 5                    0.027    DEM    0.135
# 6                    0.016    DEM    0.200
# 7                    0.014    DEM    0.190
# 8                    0.025    DEM    0.867
# 9                    0.009    REP   -0.033
# 10                   0.012    DEM    0.002
# 11                   0.020    DEM    0.294
# 12                   0.031    REP   -0.307
# 13                   0.019    DEM    0.198
# 14                   0.020    REP   -0.160
# 15                   0.020    REP   -0.082
# 16                   0.024    REP   -0.148
# 17                   0.018    REP   -0.259
# 18                   0.017    REP   -0.186
# 19                   0.029    DEM    0.087
# 20                   0.025    DEM    0.332
# 21                   0.023    DEM    0.335
# 22                   0.015    DEM    0.028
# 23                   0.023    DEM    0.071
# 24                   0.014    REP   -0.165
# 25                   0.018    REP   -0.154
# 26                   0.029    REP   -0.163
# 27                   0.026    REP   -0.190
# 28                   0.023    DEM    0.024
# 29                   0.017    DEM    0.073
# 30                   0.016    DEM    0.158
# 31                   0.022    DEM    0.108
# 32                   0.014    DEM    0.232
# 33                   0.015    REP   -0.013
# 34                   0.031    REP   -0.333
# 35                   0.015    REP   -0.081
# 36                   0.023    REP   -0.331
# 37                   0.032    DEM    0.161
# 38                   0.013    DEM    0.012
# 39                   0.020    DEM    0.206
# 40                   0.015    REP   -0.117
# 41                   0.026    REP   -0.262
# 42                   0.019    REP   -0.233
# 43                   0.015    REP   -0.055
# 44                   0.042    REP   -0.205
# 45                   0.032    DEM    0.354
# 46                   0.019    DEM    0.101
# 47                   0.033    DEM    0.192
# 48                   0.017    REP   -0.389
# 49                   0.017    DEM    0.007
# 50                   0.035    REP   -0.433

# %% [markdown]
# ##### Findings
# This graph shows the relationship between the margin of winning to the proportion of independent votes per state. The graph shows that as the margin of winning becomes greater, the proportion of independent votes increases. The graph also shows that there is a greater proportion of independent votes when Republicans win, compared to when Democrats win.

# %% [markdown]
# #### Subquestion 3: How often does a state’s presidential party vote match the senator, house rep and governor party?

# %% [markdown]
# I query variables from the the merged dataframe to identify frequency of states that have the same political party across their overall presidential, senate, house, and governor elections. To organize the data, I sorted all information into a table.
#
# The senate and governor datasets only included 34 and 11 participating states, respectively. Raw counts alone may be misleading, so I also calculated proportions. For example, among the 34 states that did elect new senators or the 11 states that did elect new governors, repectively, what proportion of these align with the overall state presidential party?

# %%
labels = [ #column with descriptions for which type of election we're comparing political parties to 
    "President vs Senate",
    "President vs House Majority",
    "President vs Governor",
    "President vs Senate & House",
    "President vs Senate, House & Governor"
    ]

raw_counts = [ #number of states that have the same political party between presidential and respective election listed below
    len(merged.query("Winner == Senator_Party")), #compute number of obs. that have same string (party) under "Winner" col and "Senator_Party" col
    len(merged.query("Winner == House_Majority")),
    len(merged.query("(Winner == Governor_Party)")), 
    len(merged.query("(Winner == House_Majority) and (Winner==Senator_Party)")), 
    len(merged.query("(Winner == House_Majority) and (Winner==Senator_Party) and (Winner==Governor_Party)"))
    ]

proportions = [ #proportions of number of political party matches among states that actually participated in different elections
    len(merged.query("Winner == Senator_Party"))/len(sen["state"].unique()),  # number of presidential & senate matches / 34 states that actually held senator elections
    len(merged.query("Winner == House_Majority"))/len(house["States"].unique()), #denominator computes number of unique strings under "state" column
    len(merged.query("(Winner == Governor_Party)"))/len(gov["state"].unique()), # number of presidential & governor matches / 11 states that actually held senator elections
    len(merged.query("(Winner == House_Majority) and (Winner==Senator_Party)"))/len(pres["state"].unique()), # number of presidential & senate & house matches / all states
    len(merged.query("(Winner == House_Majority) and (Winner==Senator_Party) and (Winner==Governor_Party)"))/len(pres["state"].unique())
]

relevant_states = [#list all states that have the political party matches
    merged.query("Winner == Senator_Party")["State"].tolist(), #grab the specific states with matching political parties between president and senator
    merged.query("Winner == House_Majority")["State"].tolist(), #.tolist converts series to list; better formatting
    merged.query("(Winner == Governor_Party)")["State"].tolist(),
    merged.query("(Winner == House_Majority) and (Winner==Senator_Party)")["State"].tolist(),
    "N/A"
]
match_table = pd.DataFrame({"Comparisons": labels , "Number_of_States" : raw_counts, "Proportion" : proportions, "Relevant_States" : relevant_states})
display(round(match_table,2)) #create and round dataframe

###########################################################################################################################################################################################

# Bar plots created from information in table 
# Raw counts of number of matches 
categories = ["Senate", "House", "Governor", "Senate\nand House", "Senate, House\nand Governor"] #x-axis labels
num_states = raw_counts #number of states with political party matches taken from table above

plt.bar(x = categories, height = num_states, color = "hotpink") #create bar plot
plt.xlabel("Type of Election")
plt.ylabel("Number of States")
plt.title("Frequency of Overall State Presidential Party Match\nAgainst House, Senate, and Governor")
plt.show()

#Proportions of matches among states that participated for each elected position
categories = ["Senate", "House", "Governor"]
proportions_state = [    #taken from table above
    len(merged.query("Winner == Senator_Party"))/len(sen["state"].unique()),
    len(merged.query("Winner == House_Majority"))/len(house["States"].unique()),
    len(merged.query("(Winner == Governor_Party)"))/len(gov["state"].unique())]

plt.bar(x = categories, height = proportions_state, color = "pink")
plt.xlabel("Type of Election")
plt.ylabel("Proportion of States")
plt.title("Proportions of Matches Against Overall State Presidential Party")
plt.show()
# Out:
#                              Comparisons  Number_of_States  Proportion  \
# 0                    President vs Senate                 4        0.12
# 1            President vs House Majority                45        0.88
# 2                  President vs Governor                 8        0.73
# 3            President vs Senate & House                 3        0.06
# 4  President vs Senate, House & Governor                 0        0.00
#
#                                      Relevant_States
# 0           [Maine, Michigan, North Carolina, Texas]
# 1  [Alabama, Alaska, Arizona, Arkansas, Californi...
# 2  [Delaware, Indiana, Missouri, Montana, North D...
# 3                     [Maine, North Carolina, Texas]
# 4                                                N/A

# %% [markdown]
# ##### Findings:
# The first bar graph compares the raw count of states that have the same political party between their senate, house, and governor elections when compared to overall presidential elections.
# The second bar graph provides the proportion of states that have the same political party as their overall presidential party, AMONG the ones that did particpate in elections for their respective groups in the x-axis. For instance, among the 34 states that elected new senators in the 2020 US Elections, ~12% had the same political group for their senator and president.
#
# For the most part, political parties were identical across presidential and house majority elections. A large proportion of states that did elect new governors for the 2020 cycle also had an identical political party to their presidential party. The frequency just appears lower due the limited governors elected. This information is consistent with what we'd expect in that states with a general political ideology will opt to elect leaders with identify in the same party.
# What stands out is the how many senators elected identified with political parties that were different than their state's presidential party. This could be due to other factors such as geography, economic standing, and education level of voters in the state. Future research could look into these variables and obtain a more detailed dataset.

# %% [markdown]
# #### Subquestion 4: What percentage of the time do the chosen president, senator, house representative, and governor match in party for presidential swing states?

# %%
# getting margin of democrat win
pres_proportions["margin"] = pres_proportions["Proportion_Democrat"] - pres_proportions["Proportion_Republican"]

# taking absolute value
pres_proportions["margin_abs"] = abs(pres_proportions["margin"])

# filtering for states with <5% margin of winning -> our definition of "swing states"
swing = pres_proportions.query("margin_abs <= 0.05")

# getting names of swing states
swing_list = swing["State"].tolist()

# displaying the 8 swing states + which party won in that state for president
swing_winner = swing[["State", "Winner"]]
display(swing_winner)
# Out:
#              State Winner
# 2          Arizona    DEM
# 9          Florida    REP
# 10         Georgia    DEM
# 22        Michigan    DEM
# 28          Nevada    DEM
# 33  North Carolina    REP
# 38    Pennsylvania    DEM
# 49       Wisconsin    DEM

# %%
# filtering for swing states in senate
sen_swing = sen_proportions.query("State in @swing_list")

# filtering for swing states in house
house_swing = house_proportions.query("State in @swing_list")

# merging senate and presidential dataframes for swing states together 
swing_sen_pres = pd.merge(left = swing[["State","Winner"]], 
    right = sen_swing[["State", "Winner"]], 
    how = "left", on = "State")

# renaming
swing_sen_pres = swing_sen_pres.rename(columns = {"Winner_x" : "Winner", "Winner_y" : "Senator_Party"})

# merging all dataframes for swing states together
swing_merged = pd.merge(left = swing_sen_pres, 
    right = house_swing[["State", "House_Majority"]], 
    how = "left", on = "State")

# %%
# getting number of matches between each pairwise comparison
# president and senate
pres_sen_match = swing_merged.query("Winner == Senator_Party")
n_pres_sen = len(pres_sen_match) # raw
prop_pres_sen = n_pres_sen/len(sen_swing) # proportion

# president and house
pres_house_match = swing_merged.query("Winner == House_Majority")
n_pres_house = len(pres_house_match) # raw
prop_pres_house = n_pres_house/len(house_swing) # proportion

# all
all_match = swing_merged.query("Winner == Senator_Party == House_Majority")
n_all_match = len(all_match) # raw
prop_all = n_all_match/len(swing_merged) # proportion

# %%
# plotting number of matches across different pairwise comparisons
match_cats = ["President-Senate", "President-House", "All"]
match_list = [prop_pres_sen, prop_pres_house, prop_all]

plt.bar(x = match_cats, height = match_list, color = "purple")
plt.xlabel("Type of Comparison")
plt.ylabel("Proportion of Matching Winning Party")
plt.title("Proportions of Matching Winning Party Between \n Branches of Government in Swing States")
plt.show()

# %% [markdown]
# ##### Findings:
# After filtering for states that had a margin of victory of less than 0.05 in the presidental election (in other words, either Democrat or Republican won by less than 5% of votes), we were left with 8 states, which we termed "swing states". The swing states and which party narrowly won in that state are displayed in a table under the beginning of Subquestion 4.
#
# When comparing the winning party for president, senate, and house across the swing states, we found that half of the swing states agreed when it came to voting the same party for president and senator, and for president and house as well. This makes sense given that we would most likely expect swing states, on average, to swing right or left 50% of the time. However, when comparing looking at the rate of agreement for house, senate, and president, we observe only a 1/8 chance of a swing state voting for the same party in all three institutions (senate, state, government). This may be in part due to the fact that only 4 out of the 8 swing states were available in the senate_county_candidate.csv dataset.

# %% [markdown]
# #### Subquestion 5: What are the proportions of Democrats and Republicans in the senate and house compared to the winning margin of presidential swing states?

# %%
cats = swing["State"].tolist() # created a list of states that are presidential swings

senate = sen_proportions.query("State in @cats") # took the senate proportions of states that are presidential swings
senate_list = senate["State"].tolist()

pres_swing = pres_proportions.query("State in @senate_list") # took the presidential proportions of states that are presidential swings    
presswing_list = pres_swing["Winner"].tolist()

paired = list(zip(senate_list, presswing_list))

v1, v2 = senate["Proportion_Democrat"], senate["Proportion_Republican"] # variables to be plotted
w, x = 0.4, np.arange(len(paired)) # width and location

# plotting
plt.bar(x - w/2, v1, w, label='Dem')
plt.bar(x + w/2, v2, w, label='Rep')

plt.xticks(x, paired, rotation=45)
plt.xlabel("Presidential Swing States and Presidential Party Voted")
plt.ylabel('Proportions')
plt.title('Democrat vs. Republican Proportions in the Senate \nin Presidential Swing States')
plt.legend()
plt.show()


house = house_proportions.query("State in @cats") # took the house proportions of states that are presidential swings
house_list = house["State"].tolist() # created a list of states that have house proportions of presidential swings

pres_swing_house = pres_proportions.query("State in @house_list") # took the presidential proportions of states that are presidential swings    
presswing_list_house = pres_swing_house["Winner"].tolist()

paired2 = list(zip(house_list, presswing_list_house))

v1, v2 = house["Proportion_Democrat"], house["Proportion_Republican"] # variables to be plotted
w, x = 0.4, np.arange(len(paired2)) # width and location

# plotting
plt.bar(x - w/2, v1, w, label='Dem')
plt.bar(x + w/2, v2, w, label='Rep')

plt.xticks(x, paired2, rotation=45)
plt.xlabel("Presidential Swing States and Presidential Party Voted")
plt.ylabel('Proportions')
plt.title('Democrat vs. Republican Proportions in the House \nin Presidential Swing States')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ##### Findings:
#
# The first graph shows the distribution of the Senate votes by parties in the presidential swing with the x-axis label indicating which way the presidential election ended up going while the second graph shows the same distribution but with the House of Representative. There are only 4 state senate votes in the 2020 year that were also presidential swings, so the first graph only had 4 states. The data does not have a specific pattern, meaning that swing states' house and senate votes are not correlated to their swing state status or what party ended up winning the state in the presidential election. However, there is a slight trend of the house and senate going the party direction of the presidential election.

# %% [markdown]
# #### Subquestion 6: Is there an association between the victory margin in the presidential election and the proportion of party votes in the Senate and House.

# %%
pres_props = pres_proportions.query("State != 'District of Columbia'") #removed DC because it is not a state

plt.scatter(pres_props["Dem-Rep"], house_proportions["Proportion_Democrat"], label = "Dem Win", color = "blue")
plt.scatter(pres_props["Dem-Rep"], house_proportions["Proportion_Republican"], label = "Rep Win", color = "red")
plt.xlim(-0.5, 0.5)
plt.xlabel("Dem-Rep Proportion in Presidential Election")
plt.ylabel("Proportion of Votes in House Election")
plt.title("Proportion of Votes in House vs Presidential Election")
plt.legend()
plt.show()

senate_list = sen["state"].tolist() #created a list of states that have senate proportions
pres_props2 = pres_proportions.query("State in @senate_list") #created a list of states that are in the senate list and a swing state

plt.scatter(pres_props2["Dem-Rep"], sen_proportions["Proportion_Democrat"], label = "Dem Win", color = "blue")
plt.scatter(pres_props2["Dem-Rep"], sen_proportions["Proportion_Republican"], label = "Rep Win", color = "red")
plt.xlabel("Dem-Rep Proportion in Presidential Election")
plt.ylabel("Proportion of Votes in Senate Election")
plt.title("Proportion of Votes in Senate vs Presidential Election")
plt.legend()
plt.show()

# %% [markdown]
# ##### Findings:
#
# The first graph shows the association between the winning margin of the presidential election and the republican and democratic proportion distribution in the House of representative votes. The results show that when one party win the presidential election in a state, they usually win the house in that state too. This seems reasonable since if a state usually votes one party, they will usually vote the same party between the presidential and house elections.
#
# The second graph shows the association between the winning margin of the presidential election and the republican and democratic proportion distribution in the Senate votes. These results are interesting since when one party win the presidential election in a state, the opposite party wins the senate votes in that state. A variety of factors can explain this including incumbency, votor turnout, local issues, and candidates, but further research is needed to find the exact reasoning.

# %% [markdown]
# ## Discussion:
# In summary, we found that presidential voting does generally reflect overall state political party matching. However, this pattern is not consistent across all offices, as indicated by the weak political party matching among elected senators compared to house representative and governor elections. When investigating other factors, we also find that independent voters and margin of victory between political parties provide additional context. States with a higher margin of victory, essentially a dominant presidential party, and primarily voted Republican, tend to have a higher proportion of independent participation. On the other hand, “swing states,” or those where the race between political parties was highly competitive, reported lower matching rates across offices. In these cases, presidential voting was not helpful in predicting political party alignment for the other government positions.
#
# With this, we can conclude that while presidential voting can be an accurate predictor of the overall state political position in most cases, it becomes less reliable in more nuanced contexts. In this case, we observe that swing states and senatorial elections deviate from presidential patterns. It is important to mention that we are working with limited datasets, so future analysis should further explore possible demographic, economic, or candidate-specific qualities that may have influenced the inconsistencies in party alignments.
